# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('classic')

import numpy as np
import pandas as pd
import seaborn as sns
sns.set()

# %%
#1
x=np.linspace(1,10)
x
# Out:
# array([ 1.        ,  1.18367347,  1.36734694,  1.55102041,  1.73469388,
#         1.91836735,  2.10204082,  2.28571429,  2.46938776,  2.65306122,
#         2.83673469,  3.02040816,  3.20408163,  3.3877551 ,  3.57142857,
#         3.75510204,  3.93877551,  4.12244898,  4.30612245,  4.48979592,
#         4.67346939,  4.85714286,  5.04081633,  5.2244898 ,  5.40816327,
#         5.59183673,  5.7755102 ,  5.95918367,  6.14285714,  6.32653061,
#         6.51020408,  6.69387755,  6.87755102,  7.06122449,  7.24489796,
#         7.42857143,  7.6122449 ,  7.79591837,  7.97959184,  8.16326531,
#         8.34693878,  8.53061224,  8.71428571,  8.89795918,  9.08163265,
#         9.26530612,  9.44897959,  9.63265306,  9.81632653, 10.        ])

# %%
y = np.log(x)
y
# Out:
# array([0.        , 0.16862271, 0.31287232, 0.43891304, 0.55083096,
#        0.65147448, 0.74290869, 0.82667857, 0.90397025, 0.97571415,
#        1.04265364, 1.10539198, 1.16442551, 1.22016749, 1.27296568,
#        1.32311546, 1.37086989, 1.4164474 , 1.46003784, 1.50180725,
#        1.54190171, 1.58045038, 1.61756804, 1.65335715, 1.68790953,
#        1.72130781, 1.7536266 , 1.7849335 , 1.81528997, 1.844752  ,
#        1.8733708 , 1.90119331, 1.92826263, 1.95461848, 1.98029749,
#        2.00533357, 2.02975812, 2.05360031, 2.07688726, 2.09964425,
#        2.12189486, 2.14366113, 2.16496372, 2.18582195, 2.20625398,
#        2.2262769 , 2.24590676, 2.26515869, 2.28404697, 2.30258509])

# %%
y1 = np.log2(x)
y1
# Out:
# array([0.        , 0.24327115, 0.45137935, 0.63321767, 0.79468109,
#        0.93987901, 1.07179068, 1.19264508, 1.30415339, 1.40765797,
#        1.50423123, 1.59474352, 1.6799109 , 1.76032959, 1.83650127,
#        1.90885211, 1.97774719, 2.04350164, 2.10638934, 2.16664987,
#        2.22449394, 2.28010792, 2.33365739, 2.38529016, 2.43513871,
#        2.48332224, 2.5299484 , 2.57511471, 2.61890983, 2.66141456,
#        2.70270277, 2.74284216, 2.78189494, 2.81991838, 2.85696537,
#        2.8930848 , 2.92832198, 2.96271898, 2.99631495, 3.02914635,
#        3.06124719, 3.09264929, 3.12338242, 3.15347448, 3.18295168,
#        3.21183864, 3.24015854, 3.26793321, 3.29518324, 3.32192809])

# %%
y2 = np.log10(x)
y2
# Out:
# array([0.        , 0.07323191, 0.13587872, 0.19061751, 0.23922285,
#        0.28293177, 0.32264114, 0.35902194, 0.39258929, 0.42374727,
#        0.45281872, 0.48006564, 0.50570357, 0.52991201, 0.55284197,
#        0.57462174, 0.59536123, 0.61515529, 0.63408638, 0.6522266 ,
#        0.6696394 , 0.68638088, 0.70250087, 0.71804389, 0.73304979,
#        0.74755448, 0.76159036, 0.77518677, 0.78837042, 0.80116561,
#        0.8135946 , 0.82567776, 0.83743382, 0.84888002, 0.86003227,
#        0.8709053 , 0.88151275, 0.89186728, 0.90198068, 0.91186391,
#        0.92152723, 0.9309802 , 0.94023179, 0.94929041, 0.95816393,
#        0.96685977, 0.97538491, 0.98374592, 0.991949  , 1.        ])

# %%
sns.set_style("whitegrid", {'grid.color': 'yellow'})

plt.plot(x, y)
plt.plot(x, y1)
plt.plot(x, y2)

# %%
#2
print(sns.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic']

# %%
sns.load_dataset('iris')
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.barplot(x='species', y='sepal_length', data=df)
# Out:
# <Axes: xlabel='species', ylabel='sepal_length'>

# %%
sns.barplot(x='petal_length', y='species', data=df)
# Out:
# <Axes: xlabel='petal_length', ylabel='species'>

# %%
fl=sns.load_dataset('flights')
fl
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
sns.barplot(x='year', y='passengers', hue='month',  data=fl)
# Out:
# <Axes: xlabel='year', ylabel='passengers'>

# %%
#4
di=sns.load_dataset('diamonds')
di
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
sns.scatterplot(data=di, x='carat', y='price')
# Out:
# <Axes: xlabel='carat', ylabel='price'>

# %%
sns.scatterplot(x='price', y='carat', hue='cut', data=di)
# Out:
# <Axes: xlabel='price', ylabel='carat'>

# %%
car=sns.load_dataset('car_crashes')
car
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0    18.8     7.332    5.640          18.048       15.040       784.55
# 1    18.1     7.421    4.525          16.290       17.014      1053.48
# 2    18.6     6.510    5.208          15.624       17.856       899.47
# 3    22.4     4.032    5.824          21.056       21.280       827.34
# 4    12.0     4.200    3.360          10.920       10.680       878.41
# 5    13.6     5.032    3.808          10.744       12.920       835.50
# 6    10.8     4.968    3.888           9.396        8.856      1068.73
# 7    16.2     6.156    4.860          14.094       16.038      1137.87
# 8     5.9     2.006    1.593           5.900        5.900      1273.89
# 9    17.9     3.759    5.191          16.468       16.826      1160.13
# 10   15.6     2.964    3.900          14.820       14.508       913.15
# 11   17.5     9.450    7.175          14.350       15.225       861.18
# ...

# %%
corr=car.corr()
corr
# Out:
# C:\Users\ACER\AppData\Local\Temp\ipykernel_9024\84883454.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr=car.corr()
#                    total  speeding   alcohol  not_distracted  no_previous  \
# total           1.000000  0.611548  0.852613        0.827560     0.956179
# speeding        0.611548  1.000000  0.669719        0.588010     0.571976
# alcohol         0.852613  0.669719  1.000000        0.732816     0.783520
# not_distracted  0.827560  0.588010  0.732816        1.000000     0.747307
# no_previous     0.956179  0.571976  0.783520        0.747307     1.000000
# ins_premium    -0.199702 -0.077675 -0.170612       -0.174856    -0.156895
# ins_losses     -0.036011 -0.065928 -0.112547       -0.075970    -0.006359
#
#                 ins_premium  ins_losses
# total             -0.199702   -0.036011
# ...

# %%
heatmap = sns.heatmap(corr, annot=True)
heatmap.set_title("Car crashes correlation")
# Out:
# Text(0.5, 1.0, 'Car crashes correlation')
